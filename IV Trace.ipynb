# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import numpy as np
import phm

# %%
p = phm.phm()

# %%
p.select_adc(0)
p.set_adc_delay(100)

VA = np.linspace(0,5e3,100)
VB = np.zeros_like(VA)
for i,va in enumerate(VA):
  p.set_voltage(va)
  time.sleep(0.001)
  t, vb = p.get_voltage()
  VB[i] = vb

# %%
plot(VA, 1e-3 * (VA-VB))
xlabel("mV")
ylabel("mA")
