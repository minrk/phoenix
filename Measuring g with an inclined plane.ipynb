# %%
from IPython.display import display, Latex, Math

# %%
import phm

# %%
p = phm.phm()

# %%
bin(p.read_inputs())
# Out:
# '0b1111'

# %%
shutup = lambda : p.set_frequency(0)

def shutup_handler(self, etype, value, tb, tb_offset=None):
    shutup()
    print 'KeyboardInterrupt'

get_ipython().set_custom_exc((KeyboardInterrupt,), shutup_handler)

# %%
def notify_speaker():
    p.set_frequency(50)

def notify_led():
    p.set_voltage(3000)

notify = notify_speaker

# %%
p.write_outputs(0b1111)

# %% [markdown]
# test the photo gate

# %%
f = 0
stepup = 10
stepdown = stepup * 3
dt = 0.1
fmax = 550
while True:
    d = p.read_inputs()
    if d is None:
        continue

    if d & 0b1000:
        f += stepup
        f = min(f, fmax)
    else:
        f -= stepdown
        f = max(0,f)
    p.set_frequency(f)
    time.sleep(dt)
# Out:
# KeyboardInterrupt

# %%
notify_speaker()

# %%
shutup()
# Out:
# 0

# %% [markdown]
# Activate the magnet

# %%
def magnetize():
    p.write_outputs(0b1000)

def drop():
    p.write_outputs(0b0010)

# %%
magnetize()

# %% [markdown]
# Now we measure time:
#
# - drop the ball
# - poll the light barrier for when the ball crosses its path

# %%
tempo = 600

# %%
def wait(beats=3):
    time.sleep(beats * 60. / tempo)

C4 = 130.81
def ready_beep(beats=1):
    p.write_outputs(0b1100)
    p.set_frequency(C4)
    wait(beats)
    p.write_outputs(0b1000)
    p.set_frequency(0)

def go_beep(beats=1):
    p.write_outputs(0b1010)
    p.set_frequency(C4*2)
    wait(beats)
    p.set_frequency(0)

def catch_beep(beats=1):
    p.write_outputs(0b1110)
    p.set_frequency(C4*4)
    wait(beats)
    p.set_frequency(0)
    p.write_outputs(0b000)

# %%
def time_drop():
    print "waiting for signal ...",
    sys.stdout.flush()
    while p.read_inputs() is None or not p.read_inputs() & 0b1000:
        time.sleep(0.1)
    print "ready ...",
    sys.stdout.flush()
    while p.read_inputs() is None or p.read_inputs() & 0b1000:
        ready_beep()
        wait(4)
    go_beep(3)
    print "go!"
    sys.stdout.flush()
    start = time.time()
    drop()
    cycles = 0
    while not p.read_inputs() & 0b1000:
        cycles += 1
    stop = time.time()
    t = stop - start
    err = 0.5 * t / cycles
    t -= err
    tms = 1e3*t
    print u"%i ± %.1f ms" % (1e3 * t, 1e3 * err)
    catch_beep()
    magnetize()
    return t, err

# %%
time_drop()
# Out:
# waiting for signal ...
#  ready ...
#  go!
# 1485 ﾱ 4.0 ms
# (1.4855561643033415, 0.004025897464236697)

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
ds = [0, 5, 10, 15, 20, 25, 30][:4]
ts = [0]
errs = [0]

for d in ds[1:]:
    print "move magnet to %i cm" % d
    t, err = time_drop()
    ts.append(t)
    errs.append(err)

ds = np.array(ds)
ts = np.array(ts)
errs = np.array(errs)
plot(ds, ts, '-o')
# Out:
# move magnet to 5 cm
# waiting for signal ...
#  ready ...
#  go!
# 396 ﾱ 4.2 ms
# move magnet to 10 cm
# waiting for signal ...
#  ready ...
#  go!
# 539 ﾱ 4.1 ms
# move magnet to 15 cm
# waiting for signal ...
#  ready ...
#  go!
# 651 ﾱ 4.1 ms

# %% [markdown]
# <img src="files/incline.png" width="480px"/>

# %% [markdown]
# So we have the force pulling the ball down the incline:
#
#
# $F = mg$ $sin(\theta)$
#
# And the distance to the bottom $d$.
# The position of the ball along the plane is described by
#
# $\ddot x = g$ $sin(\theta)$
#
# Which we can integrate with the initial conditions
#
# $x(0) = \dot x(0) = 0$
#
# so we get
#
# $\dot x =  gt$ $sin(\theta)$
#
# $x(t) = \frac{1}{2} g t^2$ $sin(\theta)$
#
# And we are measuring $t$ where $x(t) = d$,
# so we have the equation
#
# $d = \frac{1}{2} g t^2$ $sin(\theta)$
#
# where $d$ is known and $t$ is measured,
# so we now have a relationship for $g$ and $\theta$:
#
# $sin(\theta) = \frac{2 d}{g t^2}$
#
# $g = \frac{2 d}{ t^2 sin(\theta)}$

# %% [markdown]
# From our measurements of $t$ and $d$,
# we can get an expression for $g$ $sin(\theta)$
# by doing a least-squares fit for a second order polynomial,
# of the form:
#
# $d = a t^2$
#
# where
#
# $a = \frac{1}{2} g$ $sin(\theta)$

# %%
plot(ts, ds, '-o')
xlabel("t")
ylabel("d")

# %% [markdown]
# Now do a least-squares fit for $a$ in
#
# $d = a t ^ 2$

# %%
from scipy.optimize import leastsq

err_f = lambda a: a*ts*ts - ds

a = leastsq(err_f, 1)[0][0]

# %%
tt = np.linspace(0, ts[-1])
plot(tt, a * tt**2, '-', ts, ds, '-o');

# %% [markdown]
# and
#
# $g$ $sin(\theta) = 2 a$

# %%
g_sin_theta = 2 * a

# %% [markdown]
# If we measure the elevation of the 30cm mark,
# we can get
#
# $sin(\theta) = \frac{h}{30cm}$

# %%
sin_theta = 2.1 / 30

# %% [markdown]
# Which we can now plug into the above equation,
# solving for $g$
#
# $g = \frac{2 a} {sin(\theta)}$

# %%
display(Latex("$g = %.1f$ cm/s" % (g_sin_theta / sin_theta)))
# Out:
# $g = 981.0$ cm/s

# %% [markdown]
# which is hopefully close to the true value of 980.7
